# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
raw_csv_data = pd.read_csv('yfinance_2020_apr_14.csv')

# %%
df_comp = raw_csv_data.copy()

# %%
df_comp
# Out:
#             Date          spx           dax         ftse        nikkei
# 0     1994-01-07   469.899994   2224.949951  3446.000000  18124.009766
# 1     1994-01-10   475.269989   2225.000000  3440.600098  18443.439453
# 2     1994-01-11   474.130005   2228.100098  3413.800049  18485.250000
# 3     1994-01-12   474.170013   2182.060059  3372.000000  18793.880859
# 4     1994-01-13   472.470001   2142.370117  3360.000000  18577.259766
# ...          ...          ...           ...          ...           ...
# 6847  2020-04-07  2659.409912  10356.700195  5704.500000  18950.179688
# 6848  2020-04-08  2749.979980  10332.889648  5677.700195  19353.240234
# 6849  2020-04-09  2789.820068  10564.740234  5842.700195  19345.769531
# 6850  2020-04-10  2789.820068  10564.740234  5842.700195  19498.500000
# 6851  2020-04-13  2761.629883  10564.740234  5842.700195  19043.400391
#
# [6852 rows x 5 columns]

# %%
df_comp.set_index('Date', inplace = True)

# %%
df_comp
# Out:
#                     spx           dax         ftse        nikkei
# Date
# 1994-01-07   469.899994   2224.949951  3446.000000  18124.009766
# 1994-01-10   475.269989   2225.000000  3440.600098  18443.439453
# 1994-01-11   474.130005   2228.100098  3413.800049  18485.250000
# 1994-01-12   474.170013   2182.060059  3372.000000  18793.880859
# 1994-01-13   472.470001   2142.370117  3360.000000  18577.259766
# ...                 ...           ...          ...           ...
# 2020-04-07  2659.409912  10356.700195  5704.500000  18950.179688
# 2020-04-08  2749.979980  10332.889648  5677.700195  19353.240234
# 2020-04-09  2789.820068  10564.740234  5842.700195  19345.769531
# 2020-04-10  2789.820068  10564.740234  5842.700195  19498.500000
# 2020-04-13  2761.629883  10564.740234  5842.700195  19043.400391
#
# [6852 rows x 4 columns]

# %%
raw_csv_data = df_comp.copy()

# %% [markdown]
# ## Visualizing All Stocks

# %%
df_comp.spx.plot(figsize = (20,5), title = "S&P500 Prices")
df_comp.dax.plot(figsize = (20,5), title = "DAX Prices")
df_comp.ftse.plot(figsize = (20,5), title = "FTSE100 Prices")
df_comp.nikkei.plot(figsize = (20,5), title = "NIKKEI Prices")
plt.legend()
plt.show()

# %% [markdown]
# ## Plotting the Quantile - Quantile Plot (Q-Q Plot)

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp.spx, plot = pylab)
pylab.show()

# %%
scipy.stats.probplot(df_comp.dax, plot = pylab)
pylab.show()

# %%
scipy.stats.probplot(df_comp.ftse, plot = pylab)
pylab.show()

# %%
scipy.stats.probplot(df_comp.nikkei, plot = pylab)
pylab.show()

# %% [markdown]
# ## Splitting the Data

# %%
size  = int(len(df_comp)*0.8)
df = df_comp.iloc[:size]
df_test = df_comp.iloc[size:]

# %%
df.tail()
# Out:
#                     spx          dax         ftse        nikkei
# Date
# 2015-01-05  2020.579956  9473.160156  6417.200195  17408.710938
# 2015-01-06  2002.609985  9469.660156  6366.500000  16883.189453
# 2015-01-07  2025.900024  9518.179688  6419.799805  16885.330078
# 2015-01-08  2062.139893  9837.610352  6570.000000  17167.099609
# 2015-01-09  2044.810059  9648.500000  6501.100098  17197.730469
